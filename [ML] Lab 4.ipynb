# %%
import pandas as pd
import numpy as np

# Load the dataset
file_path = "/content/diabetes.csv"
df = pd.read_csv(file_path)

def entropy(df, col):
    ppos = (df[col] == 1).sum()
    pneg = len(df[col]) - ppos
    total = ppos + pneg
    if ppos == 0 or pneg == 0:
        return 0
    ppos /= total
    pneg /= total
    return -ppos * np.log2(ppos) - pneg * np.log2(pneg)

def information_gain(df, feature, target):
    total_entropy = entropy(df, target)
    values, counts = np.unique(df[feature], return_counts=True)
    weighted_entropy = sum((counts[i] / sum(counts)) * entropy(df[df[feature] == values[i]], target)
                            for i in range(len(values)))
    return total_entropy - weighted_entropy

def id3(df, features, target):
    # If all target values are the same, return that class
    if len(df[target].unique()) == 1:
        return df[target].iloc[0]

    # If no features left, return the most common target value
    if not features:
        return df[target].mode()[0]

    # Compute information gain for all features
    info_gains = {feature: information_gain(df, feature, target) for feature in features}

    # Print information gain for each feature
    print("Information Gain for each feature:")
    for feature, gain in info_gains.items():
        print(f"{feature}: {gain}")

    # Select the best feature
    best_feature = max(info_gains, key=info_gains.get)
    tree = {best_feature: {}}

    # Recur for each unique value in the selected feature
    for value in df[best_feature].unique():
        sub_df = df[df[best_feature] == value].drop(columns=[best_feature])
        tree[best_feature][value] = id3(sub_df, [f for f in features if f != best_feature], target)

    return tree

def print_tree(tree, indent=""):
    if not isinstance(tree, dict):
        print(indent + "→ " + str(tree))
        return
    for key, value in tree.items():
        print(indent + str(key))
        for sub_key in value:
            print(indent + " ├── " + str(sub_key))
            print_tree(value[sub_key], indent + " │   ")

# Compute the decision tree
features = [col for col in df.columns if col != "Outcome"]
decision_tree = id3(df, features, "Outcome")

print("Decision Tree:")
print_tree(decision_tree)
# Out:
# Information Gain for each feature:
# Pregnancies: 0.0618253416801795
# Glucose: 0.30420112715337566
# BloodPressure: 0.05930957964167771
# SkinThickness: 0.08166434463609218
# Insulin: 0.2770945287640215
# BMI: 0.3438106271268244
# DiabetesPedigreeFunction: 0.6509177483835626
# Age: 0.14094080665096176
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 0.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.2516291673878229
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.8112781244591328
# Glucose: 0.8112781244591328
# BloodPressure: 0.8112781244591328
# SkinThickness: 0.8112781244591328
# Insulin: 0.8112781244591328
# BMI: 0.8112781244591328
# Age: 0.8112781244591328
# Information Gain for each feature:
# Pregnancies: 0.5849625007211563
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.4591479170272448
# Insulin: 0.2516291673878229
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.8112781244591328
# Glucose: 0.8112781244591328
# BloodPressure: 0.8112781244591328
# SkinThickness: 0.8112781244591328
# Insulin: 0.12255624891826566
# BMI: 0.8112781244591328
# Age: 0.8112781244591328
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.8112781244591328
# Glucose: 0.8112781244591328
# BloodPressure: 0.8112781244591328
# SkinThickness: 0.8112781244591328
# Insulin: 0.31127812445913283
# BMI: 0.8112781244591328
# Age: 0.8112781244591328
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.2516291673878229
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.2516291673878229
# Insulin: 0.2516291673878229
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.5
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 0.31127812445913283
# Insulin: 0.31127812445913283
# BMI: 1.0
# Age: 0.5
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 0.33333333333333337
# Insulin: 0.19087450462110944
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.0
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.2516291673878229
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.2516291673878229
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.9709505944546686
# Glucose: 0.9709505944546686
# BloodPressure: 0.9709505944546686
# SkinThickness: 0.9709505944546686
# Insulin: 0.9709505944546686
# BMI: 0.9709505944546686
# Age: 0.9709505944546686
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 0.5
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.2516291673878229
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.4199730940219749
# Glucose: 0.9709505944546686
# BloodPressure: 0.9709505944546686
# SkinThickness: 0.9709505944546686
# Insulin: 0.9709505944546686
# BMI: 0.9709505944546686
# Age: 0.9709505944546686
# Information Gain for each feature:
# Pregnancies: 0.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.8112781244591328
# Glucose: 0.8112781244591328
# BloodPressure: 0.8112781244591328
# SkinThickness: 0.8112781244591328
# Insulin: 0.8112781244591328
# BMI: 0.8112781244591328
# Age: 0.8112781244591328
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 0.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 0.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 0.0
# BMI: 1.0
# Age: 0.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.0
# Insulin: 0.0
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 0.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 0.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9709505944546686
# Glucose: 0.9709505944546686
# BloodPressure: 0.9709505944546686
# SkinThickness: 0.9709505944546686
# Insulin: 0.4199730940219749
# BMI: 0.9709505944546686
# Age: 0.9709505944546686
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 0.9709505944546686
# Glucose: 0.9709505944546686
# BloodPressure: 0.9709505944546686
# SkinThickness: 0.9709505944546686
# Insulin: 0.17095059445466854
# BMI: 0.9709505944546686
# Age: 0.5709505944546686
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.2516291673878229
# BMI: 0.9182958340544896
# Age: 0.2516291673878229
# Information Gain for each feature:
# Pregnancies: 0.5
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.8112781244591328
# Glucose: 0.8112781244591328
# BloodPressure: 0.8112781244591328
# SkinThickness: 0.8112781244591328
# Insulin: 0.0
# BMI: 0.8112781244591328
# Age: 0.8112781244591328
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.0
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 0.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.2516291673878229
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.9182958340544896
# Insulin: 0.9182958340544896
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 0.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 0.0
# Insulin: 0.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 0.9182958340544896
# Glucose: 0.9182958340544896
# BloodPressure: 0.9182958340544896
# SkinThickness: 0.2516291673878229
# Insulin: 0.0
# BMI: 0.9182958340544896
# Age: 0.9182958340544896
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Information Gain for each feature:
# Pregnancies: 1.0
# Glucose: 1.0
# BloodPressure: 1.0
# SkinThickness: 1.0
# Insulin: 1.0
# BMI: 1.0
# Age: 1.0
# Decision Tree:
# DiabetesPedigreeFunction
#  ├── 0.627
#  │   → 1
#  ├── 0.351
#  │   → 0
#  ├── 0.672
#  │   → 1
#  ├── 0.167
#  │   → 0
#  ├── 2.288
#  │   → 1
#  ├── 0.201
#  │   → 0
#  ├── 0.248
#  │   Pregnancies
#  │    ├── 3
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  ├── 0.134
#  │   → 0
#  ├── 0.158
#  │   Glucose
#  │    ├── 197
#  │    │   → 1
#  │    ├── 108
#  │    │   → 0
#  ├── 0.232
#  │   → 1
#  ├── 0.191
#  │   → 0
#  ├── 0.537
#  │   → 1
#  ├── 1.441
#  │   → 0
#  ├── 0.398
#  │   → 1
#  ├── 0.587
#  │   Glucose
#  │    ├── 166
#  │    │   → 1
#  │    ├── 44
#  │    │   → 0
#  │    ├── 91
#  │    │   → 0
#  ├── 0.484
#  │   → 1
#  ├── 0.551
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 1
#  │    ├── 3
#  │    │   → 0
#  │    ├── 8
#  │    │   → 0
#  │    ├── 1
#  │    │   → 0
#  ├── 0.254
#  │   Glucose
#  │    ├── 107
#  │    │   → 1
#  │    ├── 143
#  │    │   → 1
#  │    ├── 187
#  │    │   → 1
#  │    ├── 122
#  │    │   → 0
#  │    ├── 161
#  │    │   → 0
#  │    ├── 124
#  │    │   → 1
#  ├── 0.183
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 8
#  │    │   → 1
#  ├── 0.529
#  │   → 1
#  ├── 0.704
#  │   → 0
#  ├── 0.388
#  │   → 0
#  ├── 0.451
#  │   → 1
#  ├── 0.263
#  │   Pregnancies
#  │    ├── 9
#  │    │   → 1
#  │    ├── 5
#  │    │   → 0
#  │    ├── 10
#  │    │   → 0
#  │    ├── 0
#  │    │   → 0
#  ├── 0.205
#  │   Pregnancies
#  │    ├── 10
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  │    ├── 0
#  │    │   → 1
#  ├── 0.257
#  │   Pregnancies
#  │    ├── 7
#  │    │   → 1
#  │    ├── 2
#  │    │   → 0
#  │    ├── 13
#  │    │   → 1
#  ├── 0.487
#  │   → 0
#  ├── 0.245
#  │   Pregnancies
#  │    ├── 13
#  │    │   → 0
#  │    ├── 10
#  │    │   → 0
#  │    ├── 6
#  │    │   → 1
#  │    ├── 5
#  │    │   → 0
#  ├── 0.337
#  │   Pregnancies
#  │    ├── 5
#  │    │   → 0
#  │    ├── 7
#  │    │   → 1
#  │    ├── 2
#  │    │   → 1
#  ├── 0.546
#  │   → 0
#  ├── 0.851
#  │   → 1
#  ├── 0.267
#  │   → 0
#  ├── 0.188
#  │   → 0
#  ├── 0.512
#  │   → 0
#  ├── 0.966
#  │   → 0
#  ├── 0.42
#  │   → 0
#  ├── 0.665
#  │   → 1
#  ├── 0.503
#  │   → 1
#  ├── 1.39
#  │   → 1
#  ├── 0.271
#  │   → 0
#  ├── 0.696
#  │   → 0
#  ├── 0.235
#  │   Pregnancies
#  │    ├── 7
#  │    │   → 0
#  │    ├── 2
#  │    │   → 0
#  │    ├── 4
#  │    │   → 1
#  ├── 0.721
#  │   → 1
#  ├── 0.294
#  │   → 0
#  ├── 1.893
#  │   → 1
#  ├── 0.564
#  │   → 0
#  ├── 0.586
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 7
#  │    │   → 1
#  ├── 0.344
#  │   → 1
#  ├── 0.305
#  │   → 0
#  ├── 0.491
#  │   → 0
#  ├── 0.526
#  │   → 0
#  ├── 0.342
#  │   → 0
#  ├── 0.467
#  │   → 1
#  ├── 0.718
#  │   → 0
#  ├── 0.962
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 0
#  │    ├── 1
#  │    │   → 1
#  ├── 1.781
#  │   → 0
#  ├── 0.173
#  │   → 0
#  ├── 0.304
#  │   → 0
#  ├── 0.27
#  │   Glucose
#  │    ├── 133
#  │    │   → 1
#  │    ├── 131
#  │    │   → 1
#  │    ├── 78
#  │    │   → 0
#  │    ├── 152
#  │    │   → 0
#  ├── 0.699
#  │   → 0
#  ├── 0.258
#  │   Pregnancies
#  │    ├── 7
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  │    ├── 10
#  │    │   → 0
#  │    ├── 3
#  │    │   → 1
#  │    ├── 5
#  │    │   → 0
#  │    ├── 0
#  │    │   → 1
#  ├── 0.203
#  │   Pregnancies
#  │    ├── 5
#  │    │   → 0
#  │    ├── 0
#  │    │   → 1
#  ├── 0.855
#  │   → 1
#  ├── 0.845
#  │   → 0
#  ├── 0.334
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 0
#  │    │   → 1
#  ├── 0.189
#  │   → 0
#  ├── 0.867
#  │   → 1
#  ├── 0.411
#  │   → 0
#  ├── 0.583
#  │   Pregnancies
#  │    ├── 13
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  │    ├── 5
#  │    │   → 1
#  ├── 0.231
#  │   → 0
#  ├── 0.396
#  │   → 0
#  ├── 0.14
#  │   → 0
#  ├── 0.391
#  │   → 0
#  ├── 0.37
#  │   → 0
#  ├── 0.307
#  │   → 0
#  ├── 0.102
#  │   → 0
#  ├── 0.767
#  │   → 0
#  ├── 0.237
#  │   → 0
#  ├── 0.227
#  │   → 1
#  ├── 0.698
#  │   → 0
#  ├── 0.178
#  │   Pregnancies
#  │    ├── 13
#  │    │   → 0
#  │    ├── 6
#  │    │   → 1
#  ├── 0.324
#  │   → 0
#  ├── 0.153
#  │   Pregnancies
#  │    ├── 15
#  │    │   → 1
#  │    ├── 5
#  │    │   → 0
#  ├── 0.165
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 7
#  │    │   → 1
#  │    ├── 8
#  │    │   → 1
#  ├── 0.443
#  │   Pregnancies
#  │    ├── 4
#  │    │   → 0
#  │    ├── 8
#  │    │   → 1
#  ├── 0.261
#  │   Pregnancies
#  │    ├── 7
#  │    │   → 0
#  │    ├── 1
#  │    │   → 0
#  │    ├── 5
#  │    │   → 1
#  │    ├── 10
#  │    │   → 1
#  ├── 0.277
#  │   → 1
#  ├── 0.761
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 3
#  │    │   → 1
#  ├── 0.255
#  │   → 0
#  ├── 0.13
#  │   → 0
#  ├── 0.323
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 3
#  │    │   → 1
#  ├── 0.356
#  │   Pregnancies
#  │    ├── 6
#  │    │   → 0
#  │    ├── 3
#  │    │   → 1
#  ├── 0.325
#  │   → 1
#  ├── 1.222
#  │   → 1
#  ├── 0.179
#  │   → 0
#  ├── 0.262
#  │   → 0
#  ├── 0.283
#  │   → 0
#  ├── 0.93
#  │   → 0
#  ├── 0.801
#  │   → 0
#  ├── 0.207
#  │   → 0
#  ├── 0.287
#  │   → 0
#  ├── 0.336
#  │   → 0
#  ├── 0.247
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 1
#  │    ├── 6
#  │    │   → 0
#  ├── 0.199
#  │   → 1
#  ├── 0.543
#  │   → 1
#  ├── 0.192
#  │   → 0
#  ├── 0.588
#  │   → 1
#  ├── 0.539
#  │   → 1
#  ├── 0.22
#  │   → 1
#  ├── 0.654
#  │   → 0
#  ├── 0.223
#  │   → 0
#  ├── 0.759
#  │   → 1
#  ├── 0.26
#  │   Pregnancies
#  │    ├── 6
#  │    │   → 0
#  │    ├── 9
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  │    ├── 11
#  │    │   → 1
#  ├── 0.404
#  │   → 0
#  ├── 0.186
#  │   → 0
#  ├── 0.278
#  │   → 1
#  ├── 0.496
#  │   Glucose
#  │    ├── 88
#  │    │   → 1
#  │    ├── 102
#  │    │   → 0
#  │    ├── 116
#  │    │   → 0
#  ├── 0.452
#  │   Pregnancies
#  │    ├── 3
#  │    │   → 0
#  │    ├── 5
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  ├── 0.403
#  │   → 1
#  ├── 0.741
#  │   → 1
#  ├── 0.361
#  │   → 1
#  ├── 1.114
#  │   → 1
#  ├── 0.457
#  │   → 0
#  ├── 0.647
#  │   → 0
#  ├── 0.088
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 1
#  │    │   → 1
#  ├── 0.597
#  │   → 0
#  ├── 0.532
#  │   → 0
#  ├── 0.703
#  │   → 0
#  ├── 0.159
#  │   → 0
#  ├── 0.268
#  │   Glucose
#  │    ├── 128
#  │    │   → 0
#  │    ├── 73
#  │    │   → 0
#  │    ├── 163
#  │    │   → 1
#  │    ├── 130
#  │    │   → 0
#  │    ├── 169
#  │    │   → 1
#  ├── 0.286
#  │   Glucose
#  │    ├── 106
#  │    │   → 0
#  │    ├── 136
#  │    │   → 1
#  ├── 0.318
#  │   → 0
#  ├── 0.272
#  │   → 1
#  ├── 0.572
#  │   → 0
#  ├── 0.096
#  │   → 0
#  ├── 1.4
#  │   → 0
#  ├── 0.218
#  │   → 0
#  ├── 0.085
#  │   → 0
#  ├── 0.399
#  │   → 0
#  ├── 0.432
#  │   → 0
#  ├── 1.189
#  │   → 1
#  ├── 0.687
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 7
#  │    │   → 0
#  │    ├── 8
#  │    │   → 1
#  ├── 0.137
#  │   Pregnancies
#  │    ├── 8
#  │    │   → 1
#  │    ├── 12
#  │    │   → 0
#  ├── 0.637
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 9
#  │    │   → 1
#  ├── 0.833
#  │   → 0
#  ├── 0.229
#  │   → 0
#  ├── 0.817
#  │   → 1
#  ├── 0.204
#  │   → 0
#  ├── 0.368
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 6
#  │    │   → 1
#  ├── 0.743
#  │   → 1
#  ├── 0.722
#  │   → 1
#  ├── 0.256
#  │   → 0
#  ├── 0.709
#  │   → 0
#  ├── 0.471
#  │   → 0
#  ├── 0.495
#  │   → 0
#  ├── 0.18
#  │   Pregnancies
#  │    ├── 6
#  │    │   → 1
#  │    ├── 13
#  │    │   → 0
#  ├── 0.542
#  │   → 1
#  ├── 0.773
#  │   → 0
#  ├── 0.678
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 3
#  │    │   → 1
#  ├── 0.719
#  │   → 1
#  ├── 0.382
#  │   → 0
#  ├── 0.319
#  │   → 1
#  ├── 0.19
#  │   → 0
#  ├── 0.956
#  │   → 1
#  ├── 0.084
#  │   → 0
#  ├── 0.725
#  │   → 0
#  ├── 0.299
#  │   → 0
#  ├── 0.244
#  │   → 0
#  ├── 0.745
#  │   → 1
#  ├── 0.615
#  │   → 1
#  ├── 1.321
#  │   → 1
#  ├── 0.64
#  │   Pregnancies
#  │    ├── 8
#  │    │   → 1
#  │    ├── 5
#  │    │   → 0
#  ├── 0.142
#  │   → 0
#  ├── 0.374
#  │   → 0
#  ├── 0.383
#  │   → 1
#  ├── 0.578
#  │   → 1
#  ├── 0.136
#  │   → 0
#  ├── 0.395
#  │   → 1
#  ├── 0.187
#  │   → 0
#  ├── 0.905
#  │   → 1
#  ├── 0.15
#  │   Pregnancies
#  │    ├── 4
#  │    │   → 1
#  │    ├── 3
#  │    │   → 0
#  ├── 0.874
#  │   → 0
#  ├── 0.236
#  │   → 0
#  ├── 0.787
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 0
#  │    ├── 7
#  │    │   → 1
#  ├── 0.407
#  │   → 0
#  ├── 0.605
#  │   Pregnancies
#  │    ├── 8
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  ├── 0.151
#  │   Pregnancies
#  │    ├── 5
#  │    │   → 1
#  │    ├── 6
#  │    │   → 0
#  │    ├── 3
#  │    │   → 0
#  ├── 0.289
#  │   → 0
#  ├── 0.355
#  │   → 1
#  ├── 0.29
#  │   → 0
#  ├── 0.375
#  │   → 0
#  ├── 0.164
#  │   → 0
#  ├── 0.431
#  │   → 1
#  ├── 0.742
#  │   → 1
#  ├── 0.514
#  │   Pregnancies
#  │    ├── 5
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  ├── 0.464
#  │   → 0
#  ├── 1.224
#  │   → 1
#  ├── 1.072
#  │   → 1
#  ├── 0.805
#  │   → 1
#  ├── 0.209
#  │   Pregnancies
#  │    ├── 7
#  │    │   → 0
#  │    ├── 5
#  │    │   → 1
#  ├── 0.666
#  │   → 0
#  ├── 0.101
#  │   → 0
#  ├── 0.198
#  │   → 0
#  ├── 0.652
#  │   → 1
#  ├── 2.329
#  │   → 0
#  ├── 0.089
#  │   → 0
#  ├── 0.645
#  │   → 1
#  ├── 0.238
#  │   Pregnancies
#  │    ├── 6
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  │    ├── 4
#  │    │   → 1
#  │    ├── 3
#  │    │   → 0
#  ├── 0.394
#  │   → 0
#  ├── 0.293
#  │   Pregnancies
#  │    ├── 3
#  │    │   → 0
#  │    ├── 1
#  │    │   → 1
#  ├── 0.479
#  │   → 1
#  ├── 0.686
#  │   Glucose
#  │    ├── 179
#  │    │   → 1
#  │    ├── 107
#  │    │   → 0
#  ├── 0.831
#  │   → 1
#  ├── 0.582
#  │   → 0
#  ├── 0.446
#  │   → 0
#  ├── 0.402
#  │   → 1
#  ├── 1.318
#  │   → 1
#  ├── 0.329
#  │   → 0
#  ├── 1.213
#  │   → 1
#  ├── 0.427
#  │   → 0
#  ├── 0.282
#  │   Pregnancies
#  │    ├── 9
#  │    │   → 0
#  │    ├── 1
#  │    │   → 1
#  ├── 0.143
#  │   → 0
#  ├── 0.38
#  │   Pregnancies
#  │    ├── 9
#  │    │   → 0
#  │    ├── 4
#  │    │   → 1
#  ├── 0.284
#  │   → 0
#  ├── 0.249
#  │   → 0
#  ├── 0.926
#  │   → 1
#  ├── 0.557
#  │   Pregnancies
#  │    ├── 3
#  │    │   → 0
#  │    ├── 11
#  │    │   → 1
#  ├── 0.092
#  │   → 0
#  ├── 0.655
#  │   → 0
#  ├── 1.353
#  │   → 1
#  ├── 0.612
#  │   → 0
#  ├── 0.2
#  │   → 0
#  ├── 0.226
#  │   → 1
#  ├── 0.997
#  │   → 0
#  ├── 0.933
#  │   → 1
#  ├── 1.101
#  │   → 0
#  ├── 0.078
#  │   → 0
#  ├── 0.24
#  │   → 1
#  ├── 1.136
#  │   → 1
#  ├── 0.128
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 7
#  │    │   → 1
#  ├── 0.422
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 2
#  │    │   → 1
#  ├── 0.251
#  │   → 0
#  ├── 0.677
#  │   → 0
#  ├── 0.296
#  │   → 1
#  ├── 0.454
#  │   → 0
#  ├── 0.744
#  │   → 0
#  ├── 0.881
#  │   → 0
#  ├── 0.28
#  │   → 0
#  ├── 0.259
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  │    ├── 12
#  │    │   → 0
#  │    ├── 8
#  │    │   → 1
#  ├── 0.619
#  │   → 0
#  ├── 0.808
#  │   → 1
#  ├── 0.34
#  │   Pregnancies
#  │    ├── 4
#  │    │   → 0
#  │    ├── 5
#  │    │   → 1
#  │    ├── 2
#  │    │   → 0
#  ├── 0.434
#  │   → 0
#  ├── 0.757
#  │   → 1
#  ├── 0.613
#  │   → 1
#  ├── 0.692
#  │   Glucose
#  │    ├── 151
#  │    │   → 0
#  │    ├── 122
#  │    │   → 1
#  │    ├── 130
#  │    │   → 0
#  │    ├── 150
#  │    │   → 1
#  ├── 0.52
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 0
#  │    ├── 4
#  │    │   → 1
#  │    ├── 2
#  │    │   → 0
#  ├── 0.412
#  │   Pregnancies
#  │    ├── 14
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  ├── 0.84
#  │   → 0
#  ├── 0.839
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 1
#  │    ├── 6
#  │    │   → 0
#  ├── 0.156
#  │   → 0
#  ├── 0.215
#  │   → 0
#  ├── 0.326
#  │   Pregnancies
#  │    ├── 10
#  │    │   → 1
#  │    ├── 2
#  │    │   → 0
#  ├── 1.391
#  │   → 1
#  ├── 0.875
#  │   → 1
#  ├── 0.313
#  │   → 0
#  ├── 0.433
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  ├── 0.626
#  │   → 0
#  ├── 1.127
#  │   → 1
#  ├── 0.315
#  │   → 0
#  ├── 0.345
#  │   → 1
#  ├── 0.129
#  │   → 1
#  ├── 0.527
#  │   → 0
#  ├── 0.197
#  │   Pregnancies
#  │    ├── 3
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  │    ├── 1
#  │    │   → 0
#  ├── 0.731
#  │   → 1
#  ├── 0.148
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 4
#  │    │   → 0
#  │    ├── 9
#  │    │   → 1
#  ├── 0.123
#  │   → 0
#  ├── 0.127
#  │   → 1
#  ├── 0.122
#  │   → 0
#  ├── 1.476
#  │   → 0
#  ├── 0.166
#  │   → 0
#  ├── 0.932
#  │   → 0
#  ├── 0.343
#  │   Pregnancies
#  │    ├── 5
#  │    │   → 1
#  │    ├── 2
#  │    │   → 0
#  ├── 0.893
#  │   → 1
#  ├── 0.331
#  │   → 1
#  ├── 0.472
#  │   → 0
#  ├── 0.673
#  │   → 0
#  ├── 0.389
#  │   → 0
#  ├── 0.485
#  │   → 0
#  ├── 0.349
#  │   Pregnancies
#  │    ├── 8
#  │    │   → 0
#  │    ├── 1
#  │    │   → 1
#  ├── 0.279
#  │   → 0
#  ├── 0.346
#  │   → 1
#  ├── 0.252
#  │   → 0
#  ├── 0.243
#  │   → 0
#  ├── 0.58
#  │   → 0
#  ├── 0.559
#  │   → 0
#  ├── 0.302
#  │   → 1
#  ├── 0.569
#  │   → 1
#  ├── 0.378
#  │   Pregnancies
#  │    ├── 12
#  │    │   → 0
#  │    ├── 5
#  │    │   → 1
#  ├── 0.385
#  │   → 0
#  ├── 0.499
#  │   → 0
#  ├── 0.306
#  │   → 0
#  ├── 0.234
#  │   Glucose
#  │    ├── 133
#  │    │   → 1
#  │    ├── 91
#  │    │   → 0
#  ├── 2.137
#  │   → 1
#  ├── 1.731
#  │   → 0
#  ├── 0.545
#  │   → 0
#  ├── 0.225
#  │   → 0
#  ├── 0.816
#  │   → 0
#  ├── 0.528
#  │   Pregnancies
#  │    ├── 12
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  ├── 0.509
#  │   → 0
#  ├── 1.021
#  │   → 0
#  ├── 0.821
#  │   → 0
#  ├── 0.947
#  │   → 0
#  ├── 1.268
#  │   → 0
#  ├── 0.221
#  │   → 0
#  ├── 0.66
#  │   Pregnancies
#  │    ├── 5
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  ├── 0.239
#  │   → 1
#  ├── 0.949
#  │   → 0
#  ├── 0.444
#  │   → 0
#  ├── 0.463
#  │   → 0
#  ├── 0.803
#  │   → 1
#  ├── 1.6
#  │   → 0
#  ├── 0.944
#  │   → 0
#  ├── 0.196
#  │   → 1
#  ├── 0.241
#  │   → 1
#  ├── 0.161
#  │   Pregnancies
#  │    ├── 4
#  │    │   → 1
#  │    ├── 7
#  │    │   → 0
#  ├── 0.135
#  │   → 1
#  ├── 0.376
#  │   → 1
#  ├── 1.191
#  │   → 1
#  ├── 0.702
#  │   → 1
#  ├── 0.674
#  │   Pregnancies
#  │    ├── 6
#  │    │   → 0
#  │    ├── 2
#  │    │   → 1
#  ├── 1.076
#  │   → 0
#  ├── 0.534
#  │   → 1
#  ├── 1.095
#  │   → 0
#  ├── 0.554
#  │   → 1
#  ├── 0.624
#  │   → 0
#  ├── 0.219
#  │   Pregnancies
#  │    ├── 3
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  ├── 0.507
#  │   → 0
#  ├── 0.561
#  │   → 0
#  ├── 0.421
#  │   → 0
#  ├── 0.516
#  │   → 1
#  ├── 0.264
#  │   → 1
#  ├── 0.328
#  │   → 1
#  ├── 0.233
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 1
#  │    ├── 0
#  │    │   → 0
#  ├── 0.108
#  │   → 0
#  ├── 1.138
#  │   → 0
#  ├── 0.147
#  │   → 0
#  ├── 0.727
#  │   Glucose
#  │    ├── 107
#  │    │   → 0
#  │    ├── 0
#  │    │   → 1
#  ├── 0.435
#  │   → 1
#  ├── 0.497
#  │   → 0
#  ├── 0.23
#  │   Pregnancies
#  │    ├── 4
#  │    │   → 0
#  │    ├── 9
#  │    │   → 1
#  ├── 0.955
#  │   → 1
#  ├── 2.42
#  │   → 1
#  ├── 0.658
#  │   → 0
#  ├── 0.33
#  │   → 0
#  ├── 0.51
#  │   → 1
#  ├── 0.285
#  │   → 0
#  ├── 0.415
#  │   → 0
#  ├── 0.381
#  │   → 0
#  ├── 0.832
#  │   → 0
#  ├── 0.498
#  │   → 0
#  ├── 0.212
#  │   → 1
#  ├── 0.364
#  │   Pregnancies
#  │    ├── 5
#  │    │   → 0
#  │    ├── 0
#  │    │   → 1
#  ├── 1.001
#  │   → 1
#  ├── 0.46
#  │   → 0
#  ├── 0.733
#  │   → 0
#  ├── 0.416
#  │   → 0
#  ├── 0.705
#  │   → 0
#  ├── 1.022
#  │   → 0
#  ├── 0.269
#  │   → 0
#  ├── 0.6
#  │   → 0
#  ├── 0.571
#  │   → 0
#  ├── 0.607
#  │   → 0
#  ├── 0.17
#  │   → 0
#  ├── 0.21
#  │   → 0
#  ├── 0.126
#  │   → 0
#  ├── 0.711
#  │   → 1
#  ├── 0.466
#  │   → 0
#  ├── 0.162
#  │   → 0
#  ├── 0.419
#  │   → 0
#  ├── 0.63
#  │   → 1
#  ├── 0.365
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 1
#  │    ├── 1
#  │    │   → 0
#  ├── 0.536
#  │   Pregnancies
#  │    ├── 1
#  │    │   → 0
#  │    ├── 4
#  │    │   → 1
#  ├── 1.159
#  │   → 0
#  ├── 0.629
#  │   → 0
#  ├── 0.292
#  │   → 0
#  ├── 0.145
#  │   → 0
#  ├── 1.144
#  │   → 1
#  ├── 0.174
#  │   → 0
#  ├── 0.547
#  │   → 0
#  ├── 0.163
#  │   → 1
#  ├── 0.738
#  │   → 0
#  ├── 0.314
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 1
#  │    ├── 3
#  │    │   → 0
#  ├── 0.968
#  │   Pregnancies
#  │    ├── 2
#  │    │   → 0
#  │    ├── 3
#  │    │   → 1
#  ├── 0.409
#  │   → 0
#  ├── 0.297
#  │   → 1
#  ├── 0.525
#  │   → 0
#  ├── 0.154
#  │   → 0
#  ├── 0.771
#  │   → 1
#  ├── 0.107
#  │   → 0
#  ├── 0.493
#  │   → 0
#  ├── 0.717
#  │   → 0
#  ├── 0.917
#  │   → 0
#  ├── 0.501
#  │   → 0
#  ├── 1.251
#  │   → 0
#  ├── 0.735
#  │   → 0
#  ├── 0.804
#  │   → 0
#  ├── 0.661
#  │   → 1
#  ├── 0.549
#  │   → 1
#  ├── 0.825
#  │   → 1
#  ├── 0.423
#  │   → 1
#  ├── 1.034
#  │   → 1
#  ├── 0.16
#  │   → 0
#  ├── 0.341
#  │   → 0
#  ├── 0.68
#  │   → 0
#  ├── 0.591
#  │   → 0
#  ├── 0.3
#  │   → 0
#  ├── 0.121
#  │   Pregnancies
#  │    ├── 6
#  │    │   → 1
#  │    ├── 3
#  │    │   → 0
#  ├── 0.502
#  │   → 1
#  ├── 0.401
#  │   → 0
#  ├── 0.601
#  │   → 0
#  ├── 0.748
#  │   → 0
#  ├── 0.338
#  │   → 0
#  ├── 0.43
#  │   → 0
#  ├── 0.892
#  │   → 0
#  ├── 0.813
#  │   → 0
#  ├── 0.693
#  │   → 1
#  ├── 0.575
#  │   → 1
#  ├── 0.371
#  │   → 1
#  ├── 0.206
#  │   → 0
#  ├── 0.417
#  │   → 0
#  ├── 1.154
#  │   → 1
#  ├── 0.925
#  │   → 1
#  ├── 0.175
#  │   → 0
#  ├── 1.699
#  │   → 0
#  ├── 0.682
#  │   → 1
#  ├── 0.194
#  │   → 0
#  ├── 0.4
#  │   → 0
#  ├── 0.1
#  │   → 0
#  ├── 1.258
#  │   → 1
#  ├── 0.482
#  │   → 0
#  ├── 0.138
#  │   → 0
#  ├── 0.593
#  │   → 1
#  ├── 0.878
#  │   → 0
#  ├── 0.157
#  │   → 0
#  ├── 1.282
#  │   → 1
#  ├── 0.141
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 1
#  │    ├── 10
#  │    │   → 1
#  │    ├── 2
#  │    │   → 0
#  ├── 0.246
#  │   → 0
#  ├── 1.698
#  │   → 0
#  ├── 1.461
#  │   → 0
#  ├── 0.347
#  │   → 0
#  ├── 0.362
#  │   → 0
#  ├── 0.393
#  │   → 0
#  ├── 0.144
#  │   → 0
#  ├── 0.732
#  │   → 1
#  ├── 0.115
#  │   → 0
#  ├── 0.465
#  │   → 1
#  ├── 0.649
#  │   → 0
#  ├── 0.871
#  │   → 1
#  ├── 0.149
#  │   → 0
#  ├── 0.695
#  │   → 0
#  ├── 0.303
#  │   → 0
#  ├── 0.61
#  │   → 0
#  ├── 0.73
#  │   → 0
#  ├── 0.447
#  │   → 1
#  ├── 0.455
#  │   Pregnancies
#  │    ├── 0
#  │    │   → 1
#  │    ├── 2
#  │    │   → 0
#  ├── 0.133
#  │   → 0
#  ├── 0.155
#  │   → 0
#  ├── 1.162
#  │   → 0
#  ├── 1.292
#  │   → 1
#  ├── 0.182
#  │   → 0
#  ├── 1.394
#  │   → 1
#  ├── 0.217
#  │   → 0
#  ├── 0.631
#  │   → 0
#  ├── 0.88
#  │   → 0
#  ├── 0.614
#  │   → 0
#  ├── 0.332
#  │   → 0
#  ├── 0.366
#  │   → 0
#  ├── 0.181
#  │   → 0
#  ├── 0.828
#  │   → 0
#  ├── 0.335
#  │   → 1
#  ├── 0.856
#  │   → 0
#  ├── 0.886
#  │   → 0
#  ├── 0.439
#  │   Pregnancies
#  │    ├── 7
#  │    │   → 1
#  │    ├── 5
#  │    │   → 0
#  ├── 0.253
#  │   → 0
#  ├── 0.598
#  │   → 0
#  ├── 0.904
#  │   → 0
#  ├── 0.483
#  │   → 0
#  ├── 0.565
#  │   → 1
#  ├── 0.118
#  │   → 0
#  ├── 0.177
#  │   → 0
#  ├── 0.176
#  │   → 0
#  ├── 0.295
#  │   → 0
#  ├── 0.441
#  │   → 1
#  ├── 0.352
#  │   → 0
#  ├── 0.826
#  │   → 1
#  ├── 0.97
#  │   → 1
#  ├── 0.595
#  │   → 0
#  ├── 0.317
#  │   → 0
#  ├── 0.265
#  │   → 0
#  ├── 0.646
#  │   → 1
#  ├── 0.426
#  │   → 0
#  ├── 0.56
#  │   → 0
#  ├── 0.515
#  │   → 0
#  ├── 0.453
#  │   → 0
#  ├── 0.785
#  │   → 1
#  ├── 0.734
#  │   → 1
#  ├── 1.174
#  │   → 0
#  ├── 0.488
#  │   → 0
#  ├── 0.358
#  │   → 1
#  ├── 1.096
#  │   → 0
#  ├── 0.408
#  │   → 1
#  ├── 1.182
#  │   → 1
#  ├── 0.222
#  │   → 1
#  ├── 1.057
#  │   → 1
#  ├── 0.766
#  │   → 0
#  ├── 0.171
#  │   → 0
